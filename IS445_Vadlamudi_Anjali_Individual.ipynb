# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load tips dataset
tips = sns.load_dataset('tips')

# %%
# The tips dataset is a built-in dataset in the Seaborn package that contains information on the total bill amount, tip amount, gender, day of the week, time of day, and size of the dining party for various restaurant bills. 
# The dataset contains 244 rows and 7 columns. The columns are total bill, tip amount, sex(only male and female are included), smoker(a yes or no depending on if the person was a smoker or not), day of the wek, time of the day, size of the party.
# The data types of the columns are float64 for the total_bill and tip columns, int64 for the size column, and object for the rest of the categorical columns. 
# The dataset is interesting and helpful because it provides insights into the restaurant industry and the distribution of bills and tips based on all the categories listed above.

# %%
# Bar plot of the count of tips left by gender
sns.countplot(x='sex', hue='tip', data=tips)
plt.title('Count of Tips Left by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Swarm plot of the total bill amount vs. the tip amount, with the size indicating the size of the dining party
sns.swarmplot(x='total_bill', y='tip', hue='size', data=tips)
plt.title('Total Bill Amount vs. Tip Amount')
plt.xlabel('Total Bill Amount')
plt.ylabel('Tip Amount')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(47.097222222222214, 0.5, 'Tip Amount')

# %%
# Pair plot of the total bill amount, tip amount, and size of the dining party
sns.pairplot(tips)
plt.suptitle('Pairwise Relationships in the Tips Dataset')
# Out:
# Text(0.5, 0.98, 'Pairwise Relationships in the Tips Dataset')
